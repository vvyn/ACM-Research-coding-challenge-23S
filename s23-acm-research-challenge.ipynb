# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("/kaggle/input/star-dataset/6 class csv.csv")

df = pd.DataFrame(data) 
df0 = df[df.columns[0]]
df1 = df[df.columns[1]]
df2 = df[df.columns[2]]
df3 = df[df.columns[3]]
df4 = df[df.columns[4]]
df5 = df[df.columns[5]]
df6 = df[df.columns[6]]

ar0 = np.array(df0)
ar1 = np.array(df1)
ar2 = np.array(df2)
ar3 = np.array(df3)
ar4 = np.array(df4)
ar5 = np.array(df5)
ar6 = np.array(df6)

y = np.array(range(0, 240, 1))

# %%
df4.hist()
# Out:
# <AxesSubplot:>

# %%
#graph temperature vs star type
plt.scatter(ar4, ar0)
plt.show()

# %%
#graph star type vs luminosity
plt.scatter(ar4, ar1)
plt.show()

# %%
#graph star type vs radius
plt.scatter(ar4, ar2)
plt.show()

# %%
#graph star type vs magnitude
plt.scatter(ar4, ar3)
plt.show()

# %%
#graph star type vs star color
plt.scatter(ar4, ar5)
plt.show()

# %%
#graph star type vs spectral class
plt.scatter(ar4, ar6)
plt.show()

# %%
#graph temperature vs magnitude
plt.scatter(ar0, ar3)
plt.show()

# %%
#graph star type vs #
plt.scatter(ar4, y)
plt.show()

# %%
df.corr(method ='pearson')
# Out:
#                         Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# Temperature (K)                1.000000          0.393404      0.064216
# Luminosity(L/Lo)               0.393404          1.000000      0.526516
# Radius(R/Ro)                   0.064216          0.526516      1.000000
# Absolute magnitude(Mv)        -0.420261         -0.692619     -0.608728
# Star type                      0.411129          0.676845      0.660975
#
#                         Absolute magnitude(Mv)  Star type
# Temperature (K)                      -0.420261   0.411129
# Luminosity(L/Lo)                     -0.692619   0.676845
# Radius(R/Ro)                         -0.608728   0.660975
# Absolute magnitude(Mv)                1.000000  -0.955276
# Star type                            -0.955276   1.000000
